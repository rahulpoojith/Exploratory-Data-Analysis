# %% [markdown]
# Flight Price Prediction
#
# INTRODUCTION
#
# DATASET
#
# Dataset contains information about flight booking options from the website Easemytrip for flight travel between India's top 6 metro cities. There are 300261 datapoints and 11 features in the cleaned dataset.
#
# FEATURES
#
# The various features of the cleaned dataset are explained below:
# 1) Airline: The name of the airline company is stored in the airline column. It is a categorical feature having 6 different airlines.
# 2) Flight: Flight stores information regarding the plane's flight code. It is a categorical feature.
# 3) Source City: City from which the flight takes off. It is a categorical feature having 6 unique cities.
# 4) Departure Time: This is a derived categorical feature obtained created by grouping time periods into bins. It stores information about the departure time and have 6 unique time labels.
# 5) Stops: A categorical feature with 3 distinct values that stores the number of stops between the source and destination cities.
# 6) Arrival Time: This is a derived categorical feature created by grouping time intervals into bins. It has six distinct time labels and keeps information about the arrival time.
# 7) Destination City: City where the flight will land. It is a categorical feature having 6 unique cities.
# 8) Class: A categorical feature that contains information on seat class; it has two distinct values: Business and Economy.
# 9) Duration: A continuous feature that displays the overall amount of time it takes to travel between cities in hours.
# 10)Days Left: This is a derived characteristic that is calculated by subtracting the trip date by the booking date.
# 11) Price: Target variable stores information of the ticket price.
#
#
# OBJECTIVE
#
# To perform Exploratory Data Analysis on the dataset!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel(r'/Users/rahulpoojith/Documents/Other Datasets/Data_Train.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10678    False
# 10679    False
# 10680    False
# 10681    False
# 10682    False
# Length: 10683, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (10463, 11)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
## Feature Engineering
df['Date']=df['Date_of_Journey'].str.split('/').str[0]

# %%
df['Date']
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681    01
# 10682     9
# Name: Date, Length: 10463, dtype: object

# %%
df['Month']=df['Date_of_Journey'].str.split('/').str[1]

# %%
df['Year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10463 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Date_of_Journey  10463 non-null  object
#  2   Source           10463 non-null  object
#  3   Destination      10463 non-null  object
#  4   Route            10462 non-null  object
#  5   Dep_Time         10463 non-null  object
#  6   Arrival_Time     10463 non-null  object
#  7   Duration         10463 non-null  object
#  8   Total_Stops      10462 non-null  object
#  9   Additional_Info  10463 non-null  object
#  10  Price            10463 non-null  int64
#  11  Date             10463 non-null  object
#  12  Month            10463 non-null  object
#  13  Year             10463 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 1.2+ MB

# %%
#Converting objects to int
df['Date']=df['Date'].astype(int)

# %%
df['Month']=df['Month'].astype(int)

# %%
df['Year']=df['Year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10463 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Date_of_Journey  10463 non-null  object
#  2   Source           10463 non-null  object
#  3   Destination      10463 non-null  object
#  4   Route            10462 non-null  object
#  5   Dep_Time         10463 non-null  object
#  6   Arrival_Time     10463 non-null  object
#  7   Duration         10463 non-null  object
#  8   Total_Stops      10462 non-null  object
#  9   Additional_Info  10463 non-null  object
#  10  Price            10463 non-null  int64
#  11  Date             10463 non-null  int64
#  12  Month            10463 non-null  int64
#  13  Year             10463 non-null  int64
# dtypes: int64(4), object(10)
# memory usage: 1.2+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10463 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Date_of_Journey  10463 non-null  object
#  2   Source           10463 non-null  object
#  3   Destination      10463 non-null  object
#  4   Route            10462 non-null  object
#  5   Dep_Time         10463 non-null  object
#  6   Arrival_Time     10463 non-null  object
#  7   Duration         10463 non-null  object
#  8   Total_Stops      10462 non-null  object
#  9   Additional_Info  10463 non-null  object
#  10  Price            10463 non-null  int64
#  11  Date             10463 non-null  int64
#  12  Month            10463 non-null  int64
#  13  Year             10463 non-null  int64
# dtypes: int64(4), object(10)
# memory usage: 1.2+ MB

# %%
df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3  2019
# 1         13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882     9      6  2019
# 3         23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4         21:35   4h 45m      1 stop         No info  13302     1      3  2019

# %%
df['Arrival_Time'] = df['Arrival_Time'].apply(lambda x:x.split(' ')[0])
## To remove in arrival time the date like 22 Mar , we need only time

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year
# 0        01:10   2h 50m    non-stop         No info   3897    24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2        04:25      19h     2 stops         No info  13882     9      6  2019
# 3        23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4        21:35   4h 45m      1 stop         No info  13302     1      3  2019

# %%
df['Arrival_Hour']=df['Arrival_Time'].str.split(":").str[0]
df['Arrival_Min']=df['Arrival_Time'].str.split(":").str[1]

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# 0        01:10   2h 50m    non-stop         No info   3897    24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662     1      5  2019
#
#   Arrival_Hour Arrival_Min
# 0           01          10
# 1           13          15

# %%
df['Arrival_Hour']=df['Arrival_Hour'].astype(int)
df['Arrival_Min']=df['Arrival_Min'].astype(int)

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# 0        01:10   2h 50m    non-stop         No info   3897    24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662     1      5  2019
#
#    Arrival_Hour  Arrival_Min
# 0             1           10
# 1            13           15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10463 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Source           10463 non-null  object
#  2   Destination      10463 non-null  object
#  3   Route            10462 non-null  object
#  4   Dep_Time         10463 non-null  object
#  5   Arrival_Time     10463 non-null  object
#  6   Duration         10463 non-null  object
#  7   Total_Stops      10462 non-null  object
#  8   Additional_Info  10463 non-null  object
#  9   Price            10463 non-null  int64
#  10  Date             10463 non-null  int64
#  11  Month            10463 non-null  int64
#  12  Year             10463 non-null  int64
#  13  Arrival_Hour     10463 non-null  int64
#  14  Arrival_Min      10463 non-null  int64
# dtypes: int64(6), object(9)
# memory usage: 1.3+ MB

# %%
df.drop('Arrival_Time',axis=1,inplace=True)

# %%
df
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#       Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# ...

# %%
df['Deaprture_Hour']=df['Dep_Time'].str.split(":").str[0]
df['Departure_Min']=df['Dep_Time'].str.split(":").str[1]

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0    non-stop         No info   3897    24      3  2019             1
# 1     2 stops         No info   7662     1      5  2019            13
#
#    Arrival_Min Deaprture_Hour Departure_Min
# 0           10             22            20
# 1           15             05            50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10463 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Source           10463 non-null  object
#  2   Destination      10463 non-null  object
#  3   Route            10462 non-null  object
#  4   Dep_Time         10463 non-null  object
#  5   Duration         10463 non-null  object
#  6   Total_Stops      10462 non-null  object
#  7   Additional_Info  10463 non-null  object
#  8   Price            10463 non-null  int64
#  9   Date             10463 non-null  int64
#  10  Month            10463 non-null  int64
#  11  Year             10463 non-null  int64
#  12  Arrival_Hour     10463 non-null  int64
#  13  Arrival_Min      10463 non-null  int64
#  14  Deaprture_Hour   10463 non-null  object
#  15  Departure_Min    10463 non-null  object
# dtypes: int64(6), object(10)
# ...

# %%
df['Deaprture_Hour']=df['Deaprture_Hour'].astype(int)
df['Departure_Min']=df['Departure_Min'].astype(int)

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0    non-stop         No info   3897    24      3  2019             1
# 1     2 stops         No info   7662     1      5  2019            13
#
#    Arrival_Min  Deaprture_Hour  Departure_Min
# 0           10              22             20
# 1           15               5             50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10463 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Source           10463 non-null  object
#  2   Destination      10463 non-null  object
#  3   Route            10462 non-null  object
#  4   Dep_Time         10463 non-null  object
#  5   Duration         10463 non-null  object
#  6   Total_Stops      10462 non-null  object
#  7   Additional_Info  10463 non-null  object
#  8   Price            10463 non-null  int64
#  9   Date             10463 non-null  int64
#  10  Month            10463 non-null  int64
#  11  Year             10463 non-null  int64
#  12  Arrival_Hour     10463 non-null  int64
#  13  Arrival_Min      10463 non-null  int64
#  14  Deaprture_Hour   10463 non-null  int64
#  15  Departure_Min    10463 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 1.4+ MB

# %%
df.drop('Dep_Time',axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0    non-stop         No info   3897    24      3  2019             1
# 1     2 stops         No info   7662     1      5  2019            13
# 2     2 stops         No info  13882     9      6  2019             4
# 3      1 stop         No info   6218    12      5  2019            23
# 4      1 stop         No info  13302     1      3  2019            21
#
#    Arrival_Min  Deaprture_Hour  Departure_Min
# 0           10              22             20
# ...

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
## To find nan values
df[df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration Total_Stops Additional_Info  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m         NaN         No info
#
#       Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Deaprture_Hour  \
# 9039   7480     6      5  2019             9           25               9
#
#       Departure_Min
# 9039             45

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,np.nan:1})

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0            0         No info   3897    24      3  2019             1
# 1            2         No info   7662     1      5  2019            13
# 2            2         No info  13882     9      6  2019             4
# 3            1         No info   6218    12      5  2019            23
# 4            1         No info  13302     1      3  2019            21
#
#    Arrival_Min  Deaprture_Hour  Departure_Min
# 0           10              22             20
# ...

# %%
df[df['Total_Stops'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Duration, Total_Stops, Additional_Info, Price, Date, Month, Year, Arrival_Hour, Arrival_Min, Deaprture_Hour, Departure_Min]
# Index: []

# %%
df.drop('Route',axis=1,inplace=True)

# %%
df
# Out:
#            Airline    Source Destination Duration  Total_Stops  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0
# 1        Air India   Kolkata    Banglore   7h 25m            2
# 2      Jet Airways     Delhi      Cochin      19h            2
# 3           IndiGo   Kolkata    Banglore   5h 25m            1
# 4           IndiGo  Banglore   New Delhi   4h 45m            1
# ...            ...       ...         ...      ...          ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0
# 10679    Air India   Kolkata    Banglore   2h 35m            0
# 10680  Jet Airways  Banglore       Delhi       3h            0
# 10681      Vistara  Banglore   New Delhi   2h 40m            0
# 10682    Air India     Delhi      Cochin   8h 20m            2
#
#       Additional_Info  Price  Date  Month  Year  Arrival_Hour  Arrival_Min  \
# 0             No info   3897    24      3  2019             1           10
# ...

# %%
## tO HANDLE Duration
df['Duration_hour']=df['Duration'].str.split(' ').str[0].str.split('h').str[0]
df['Duration_min']=df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m            0         No info
# 1    Air India   Kolkata    Banglore   7h 25m            2         No info
# 2  Jet Airways     Delhi      Cochin      19h            2         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m            1         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m            1         No info
#
#    Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Deaprture_Hour  \
# 0   3897    24      3  2019             1           10              22
# 1   7662     1      5  2019            13           15               5
# 2  13882     9      6  2019             4           25               9
# 3   6218    12      5  2019            23           30              18
# 4  13302     1      3  2019            21           35              16
#
#    Departure_Min Duration_hour Duration_min
# ...

# %%
df
# Out:
#            Airline    Source Destination Duration  Total_Stops  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0
# 1        Air India   Kolkata    Banglore   7h 25m            2
# 2      Jet Airways     Delhi      Cochin      19h            2
# 3           IndiGo   Kolkata    Banglore   5h 25m            1
# 4           IndiGo  Banglore   New Delhi   4h 45m            1
# ...            ...       ...         ...      ...          ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0
# 10679    Air India   Kolkata    Banglore   2h 35m            0
# 10680  Jet Airways  Banglore       Delhi       3h            0
# 10681      Vistara  Banglore   New Delhi   2h 40m            0
# 10682    Air India     Delhi      Cochin   8h 20m            2
#
#       Additional_Info  Price  Date  Month  Year  Arrival_Hour  Arrival_Min  \
# 0             No info   3897    24      3  2019             1           10
# ...

# %%
df['Duration_min']=df['Duration_min'].fillna(00)

# %%
df
# Out:
#            Airline    Source Destination Duration  Total_Stops  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0
# 1        Air India   Kolkata    Banglore   7h 25m            2
# 2      Jet Airways     Delhi      Cochin      19h            2
# 3           IndiGo   Kolkata    Banglore   5h 25m            1
# 4           IndiGo  Banglore   New Delhi   4h 45m            1
# ...            ...       ...         ...      ...          ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0
# 10679    Air India   Kolkata    Banglore   2h 35m            0
# 10680  Jet Airways  Banglore       Delhi       3h            0
# 10681      Vistara  Banglore   New Delhi   2h 40m            0
# 10682    Air India     Delhi      Cochin   8h 20m            2
#
#       Additional_Info  Price  Date  Month  Year  Arrival_Hour  Arrival_Min  \
# 0             No info   3897    24      3  2019             1           10
# ...

# %%
df.drop('Duration_mind',axis=1,inplace=True)

# %%
df
# Out:
#            Airline    Source Destination Duration  Total_Stops  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0
# 1        Air India   Kolkata    Banglore   7h 25m            2
# 2      Jet Airways     Delhi      Cochin      19h            2
# 3           IndiGo   Kolkata    Banglore   5h 25m            1
# 4           IndiGo  Banglore   New Delhi   4h 45m            1
# ...            ...       ...         ...      ...          ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0
# 10679    Air India   Kolkata    Banglore   2h 35m            0
# 10680  Jet Airways  Banglore       Delhi       3h            0
# 10681      Vistara  Banglore   New Delhi   2h 40m            0
# 10682    Air India     Delhi      Cochin   8h 20m            2
#
#       Additional_Info  Price  Date  Month  Year  Arrival_Hour  Arrival_Min  \
# 0             No info   3897    24      3  2019             1           10
# ...

# %%
df.drop('Duration',axis=1,inplace=True)

# %%
df
# Out:
#            Airline    Source Destination  Total_Stops Additional_Info  Price  \
# 0           IndiGo  Banglore   New Delhi            0         No info   3897
# 1        Air India   Kolkata    Banglore            2         No info   7662
# 2      Jet Airways     Delhi      Cochin            2         No info  13882
# 3           IndiGo   Kolkata    Banglore            1         No info   6218
# 4           IndiGo  Banglore   New Delhi            1         No info  13302
# ...            ...       ...         ...          ...             ...    ...
# 10678     Air Asia   Kolkata    Banglore            0         No info   4107
# 10679    Air India   Kolkata    Banglore            0         No info   4145
# 10680  Jet Airways  Banglore       Delhi            0         No info   7229
# 10681      Vistara  Banglore   New Delhi            0         No info  12648
# 10682    Air India     Delhi      Cochin            2         No info  11753
#
# ...

# %%
df['Additional_Info'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10463 entries, 0 to 10682
# Series name: Additional_Info
# Non-Null Count  Dtype
# --------------  -----
# 10463 non-null  object
# dtypes: object(1)
# memory usage: 163.5+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10463 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Source           10463 non-null  object
#  2   Destination      10463 non-null  object
#  3   Total_Stops      10463 non-null  int64
#  4   Additional_Info  10463 non-null  object
#  5   Price            10463 non-null  int64
#  6   Date             10463 non-null  int64
#  7   Month            10463 non-null  int64
#  8   Year             10463 non-null  int64
#  9   Arrival_Hour     10463 non-null  int64
#  10  Arrival_Min      10463 non-null  int64
#  11  Deaprture_Hour   10463 non-null  int64
#  12  Departure_Min    10463 non-null  int64
#  13  Duration_hour    10463 non-null  object
#  14  Duration_min     10463 non-null  object
# dtypes: int64(9), object(6)
# memory usage: 1.3+ MB

# %%
df['Duration_hour'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %%
df.loc[df['Duration_hour'].str.contains('m'),'Duration_min'] = df.loc[df['Duration_hour'].str.contains('m'),'Duration_hour']

# %%
df
# Out:
#            Airline    Source Destination  Total_Stops Additional_Info  Price  \
# 0           IndiGo  Banglore   New Delhi            0         No info   3897
# 1        Air India   Kolkata    Banglore            2         No info   7662
# 2      Jet Airways     Delhi      Cochin            2         No info  13882
# 3           IndiGo   Kolkata    Banglore            1         No info   6218
# 4           IndiGo  Banglore   New Delhi            1         No info  13302
# ...            ...       ...         ...          ...             ...    ...
# 10678     Air Asia   Kolkata    Banglore            0         No info   4107
# 10679    Air India   Kolkata    Banglore            0         No info   4145
# 10680  Jet Airways  Banglore       Delhi            0         No info   7229
# 10681      Vistara  Banglore   New Delhi            0         No info  12648
# 10682    Air India     Delhi      Cochin            2         No info  11753
#
# ...

# %%
df['Duration_hour'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %%
df['Duration_hour']= df['Duration_hour'].replace('5m','0')

# %%
df
# Out:
#            Airline    Source Destination  Total_Stops Additional_Info  Price  \
# 0           IndiGo  Banglore   New Delhi            0         No info   3897
# 1        Air India   Kolkata    Banglore            2         No info   7662
# 2      Jet Airways     Delhi      Cochin            2         No info  13882
# 3           IndiGo   Kolkata    Banglore            1         No info   6218
# 4           IndiGo  Banglore   New Delhi            1         No info  13302
# ...            ...       ...         ...          ...             ...    ...
# 10678     Air Asia   Kolkata    Banglore            0         No info   4107
# 10679    Air India   Kolkata    Banglore            0         No info   4145
# 10680  Jet Airways  Banglore       Delhi            0         No info   7229
# 10681      Vistara  Banglore   New Delhi            0         No info  12648
# 10682    Air India     Delhi      Cochin            2         No info  11753
#
# ...

# %%
df['Duration_hour'].unique()
# Out:
# array([22,  5,  9, 18, 16,  8, 11, 20, 21, 17, 14,  4,  7, 10, 15,  6, 19,
#        23, 13,  2, 12,  0,  1,  3])

# %%
df['Duration_hour']=df['Duration_hour'].astype(int)

# %%
df['Duration_min']=df['Duration_min'].astype(int)

# %%
df['Duration_min']= df['Duration_min'].replace('5m','0')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10463 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Source           10463 non-null  object
#  2   Destination      10463 non-null  object
#  3   Total_Stops      10463 non-null  int64
#  4   Additional_Info  10463 non-null  object
#  5   Price            10463 non-null  int64
#  6   Date             10463 non-null  int64
#  7   Month            10463 non-null  int64
#  8   Year             10463 non-null  int64
#  9   Arrival_Hour     10463 non-null  int64
#  10  Arrival_Min      10463 non-null  int64
#  11  Deaprture_Hour   10463 non-null  int64
#  12  Departure_Min    10463 non-null  int64
#  13  Duration_hour    10463 non-null  int64
#  14  Duration_min     10463 non-null  int64
# dtypes: int64(11), object(4)
# memory usage: 1.3+ MB

# %%
from sklearn.preprocessing import   LabelEncoder

# %%
la = LabelEncoder()
for i in ["Airline","Source","Destination"]:
    df[i]=la.fit_transform(df[i])

# %%
la
# Out:
# LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10463 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  int64
#  1   Source           10463 non-null  int64
#  2   Destination      10463 non-null  int64
#  3   Total_Stops      10463 non-null  int64
#  4   Additional_Info  10463 non-null  object
#  5   Price            10463 non-null  int64
#  6   Date             10463 non-null  int64
#  7   Month            10463 non-null  int64
#  8   Year             10463 non-null  int64
#  9   Arrival_Hour     10463 non-null  int64
#  10  Arrival_Min      10463 non-null  int64
#  11  Deaprture_Hour   10463 non-null  int64
#  12  Departure_Min    10463 non-null  int64
#  13  Duration_hour    10463 non-null  int64
#  14  Duration_min     10463 non-null  int64
# dtypes: int64(14), object(1)
# memory usage: 1.3+ MB

# %%
df.drop('Additional_Info',axis=1,inplace=True)

# %%
df
# Out:
#        Airline  Source  Destination  Total_Stops  Price  Date  Month  Year  \
# 0            3       0            5            0   3897    24      3  2019
# 1            1       3            0            2   7662     1      5  2019
# 2            4       2            1            2  13882     9      6  2019
# 3            3       3            0            1   6218    12      5  2019
# 4            3       0            5            1  13302     1      3  2019
# ...        ...     ...          ...          ...    ...   ...    ...   ...
# 10678        0       3            0            0   4107     9      4  2019
# 10679        1       3            0            0   4145    27      4  2019
# 10680        4       0            2            0   7229    27      4  2019
# 10681       10       0            5            0  12648     1      3  2019
# 10682        1       2            1            2  11753     9      5  2019
#
#        Arrival_Hour  Arrival_Min  Deaprture_Hour  Departure_Min  \
# ...
